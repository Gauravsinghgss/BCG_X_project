# %% [markdown]
# ## Reading CSV file

# %%
import pandas as pd
df= pd.read_csv('E:\\Internship\\Book1.csv')
df
# Out:
#       Company  Fiscal Year  Total Revenue  Net Income  Total Assets  \
# 0         NaN          NaN            NaN         NaN           NaN
# 1   Microsoft       2021.0       168088.0     61271.0      333779.0
# 2   Microsoft       2022.0       198270.0     72738.0      364840.0
# 3   Microsoft       2023.0       211915.0     72361.0      411976.0
# 4         NaN          NaN            NaN         NaN           NaN
# 5       Tesla       2021.0        53823.0      5644.0       62131.0
# 6       Tesla       2022.0        81462.0     12587.0       82338.0
# 7       Tesla       2023.0        96773.0     14974.0      106618.0
# 8         NaN          NaN            NaN         NaN           NaN
# 9       Apple       2021.0       365817.0     94680.0      351002.0
# 10      Apple       2022.0       394328.0     99803.0      352755.0
# 11      Apple       2023.0       383285.0     96995.0      352583.0
#
#     Total Liabilities  Cash Flow from Operating Activities
# ...

# %% [markdown]
# ## Calculation of year-over-year changes

# %%
df['Revenue Growth (%)'] = df.groupby(['Company'])['Total Revenue'].pct_change() * 100
df['Net Income Growth (%)'] = df.groupby(['Company'])['Net Income'].pct_change() * 100
df['Assets Growth (%)'] = df.groupby(['Company'])['Total Assets'].pct_change() * 100
df['Liabilities Reduction (%)'] = df.groupby(['Company'])['Total Liabilities'].pct_change() * 100
df['Cash Flow Growth (%)'] = df.groupby(['Company'])['Cash Flow from Operating Activities'].pct_change() * 100

df.dropna(how='all')
# Out:
#       Company  Fiscal Year  Total Revenue  Net Income  Total Assets  \
# 1   Microsoft       2021.0       168088.0     61271.0      333779.0
# 2   Microsoft       2022.0       198270.0     72738.0      364840.0
# 3   Microsoft       2023.0       211915.0     72361.0      411976.0
# 5       Tesla       2021.0        53823.0      5644.0       62131.0
# 6       Tesla       2022.0        81462.0     12587.0       82338.0
# 7       Tesla       2023.0        96773.0     14974.0      106618.0
# 9       Apple       2021.0       365817.0     94680.0      351002.0
# 10      Apple       2022.0       394328.0     99803.0      352755.0
# 11      Apple       2023.0       383285.0     96995.0      352583.0
#
#     Total Liabilities  Cash Flow from Operating Activities  \
# 1            191791.0                              76740.0
# 2            198298.0                              89035.0
# 3            205753.0                              87582.0
# ...

# %% [markdown]
# # Conclusion
# 1. There is a reduction in net income growth and cash flow growth in Microsoft in 2023 by 0.518299% and 1.631942 respectively.
# 2. Tesla's cash flow growth reduced by 9.970117% in 2023.
# 3. Apple suffer loss in terms of revenue growth, net income growth and assets growth by 2.800461%, 2.813543% and 0.048759% respectively in 2023.
# 4. Apple's liabilities got reduced by 3.855232% in 2023 which is good for them.
